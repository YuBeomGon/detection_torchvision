# %%
import torch
import torch.nn as nn
import torchvision

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import os

from torch.utils.data import Dataset, DataLoader
# from torch.utils.data.sampler import Sampler
import torch.optim as optim
import sys
sys.path.append('../')
sys.path.append('../../')

from dataset import CocoDetection, train_transforms, val_transforms, test_transforms
from visualize import visualize
# from rcnn_model import fasterrcnn_resnet201_fpn, FastRCNNPredictor
from engine import evaluate
import utils
from models.swin import *

# %%
# !set PYTHONPATH='/home/beomgon/pytorch/LBP_scl/GenObjectDetect/'
# !export PYTHONPATH='/home/beomgon/pytorch/LBP_scl/GenObjectDetect'

# %%
import easydict 
args = easydict.EasyDict({ "batch_size": 4, 
                          "epochs": 90, 
                          "data": 0, 
                          'lr':0.002,
                         'momentum':0.9,
                         'weight_decay':1e-4,
                         'start_epoch':0,
                         'gpu':2,
                          'workers':16,
                         'print_freq':1000,
                         'output_dir':'../trained_models/retinanet_swin_t_fpn/'})

# %%
from pathlib import Path
path = Path(args.output_dir.split('checkpoint')[0])
path.mkdir(parents=True, exist_ok=True)

# %%
ngpus_per_node = torch.cuda.device_count()
print(ngpus_per_node)
GPU_NUM = args.gpu # 원하는 GPU 번호 입력
device = torch.device(f'cuda:{GPU_NUM}' if torch.cuda.is_available() else 'cpu')
torch.cuda.set_device(device)
print(device)
# Out:
# 3
# cuda:2

# %%
from models.detection.faster_rcnn import fasterrcnn_swin_t_fpn
NUM_CLASS = 91
IMG_SIZE = 448*2
model = fasterrcnn_swin_t_fpn(pretrained=False, min_size=IMG_SIZE, max_size=IMG_SIZE, num_classes=NUM_CLASS)

device = torch.device('cuda')
model.to(device)
print('model is loaded to gpu')
# Out:
# /home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1634272128894/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# return_layers {'layer1': '0', 'layer2': '1', 'layer3': '2', 'layer4': '3'}
# model is loaded to gpu

# %%
from dataset import CocoDetection, train_transforms, val_transforms, test_transforms
train_dataset = CocoDetection(root='/home/beomgon/Dataset/scl/', annFile='../../data/train.json', 
                              transforms=train_transforms)
test_dataset = CocoDetection(root='/home/beomgon/Dataset/scl/', annFile='../../data/test.json', 
                              transforms=val_transforms)
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
image, target = next(iter(train_dataset))
target
# Out:
# {'boxes': tensor([[472.5000, 667.1875, 542.9375, 743.3125]]),
#  'category_id': tensor([1]),
#  'labels': tensor([1]),
#  'image_id': tensor([1]),
#  'area': tensor([5362.0547]),
#  'iscrowd': tensor([0])}

# %%
train_sampler = torch.utils.data.RandomSampler(train_dataset)
test_sampler = torch.utils.data.SequentialSampler(test_dataset)

train_loader = DataLoader(
    train_dataset, batch_size=args.batch_size,
    sampler=train_sampler, num_workers=args.workers,
    collate_fn=utils.collate_fn)

test_loader = DataLoader(
    test_dataset, batch_size=args.batch_size,
    sampler=test_sampler, num_workers=args.workers,
    collate_fn=utils.collate_fn)

# %%
params = [p for p in model.parameters() if p.requires_grad]
# optimizer = torch.optim.Adam(params, lr=args.lr, weight_decay=args.weight_decay)
optimizer = torch.optim.SGD(
       params, lr=args.lr, momentum=args.momentum, weight_decay=args.weight_decay)
lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[15, 30, 45, 60, 75], 
                                                    gamma=0.5)

# %%
from engine import train_one_epoch

start_time = time.time()
for epoch in range(args.epochs):
    train_one_epoch(model, optimizer, train_loader, device, epoch, args.print_freq)
    lr_scheduler.step()
    
    if epoch > 60 and epoch % 5 == 0 :
        if args.output_dir:
            checkpoint = {
                'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'lr_scheduler': lr_scheduler.state_dict(),
                'args': args,
                'epoch': epoch
            }
            utils.save_on_master(
                checkpoint,
                os.path.join(args.output_dir, 'model_{}.pth'.format(epoch)))
            utils.save_on_master(
                checkpoint,
                os.path.join(args.output_dir, 'checkpoint.pth'))

    if epoch > 5 and epoch % 5 == 0 :
        # evaluate after every epoch
        evaluate(model, test_loader, device=device)    
print('total time is {}'.format(time.time() - start_time))
# Out:
# Epoch: [0]  [   0/1549]  eta: 1:39:00  lr: 0.000004  loss: 5.2863 (5.2863)  loss_classifier: 4.5537 (4.5537)  loss_box_reg: 0.0002 (0.0002)  loss_objectness: 0.7281 (0.7281)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 3.8349  data: 2.2072  max mem: 8985
# Epoch: [0]  [1000/1549]  eta: 0:06:56  lr: 0.002000  loss: 0.1655 (0.2881)  loss_classifier: 0.0600 (0.1617)  loss_box_reg: 0.0390 (0.0229)  loss_objectness: 0.0554 (0.0965)  loss_rpn_box_reg: 0.0044 (0.0070)  time: 0.7492  data: 0.0179  max mem: 9283
# Epoch: [0]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1807 (0.2504)  loss_classifier: 0.0786 (0.1318)  loss_box_reg: 0.0567 (0.0341)  loss_objectness: 0.0344 (0.0779)  loss_rpn_box_reg: 0.0038 (0.0065)  time: 0.7458  data: 0.0171  max mem: 9283
# Epoch: [0] Total time: 0:19:33 (0.7574 s / it)
# Epoch: [1]  [   0/1549]  eta: 1:18:25  lr: 0.002000  loss: 0.2701 (0.2701)  loss_classifier: 0.1216 (0.1216)  loss_box_reg: 0.1035 (0.1035)  loss_objectness: 0.0355 (0.0355)  loss_rpn_box_reg: 0.0094 (0.0094)  time: 3.0380  data: 2.2357  max mem: 9283
# Epoch: [1]  [1000/1549]  eta: 0:06:56  lr: 0.002000  loss: 0.1816 (0.1905)  loss_classifier: 0.0859 (0.0876)  loss_box_reg: 0.0598 (0.0606)  loss_objectness: 0.0276 (0.0368)  loss_rpn_box_reg: 0.0038 (0.0055)  time: 0.7607  data: 0.0225  max mem: 9283
# Epoch: [1]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1759 (0.1911)  loss_classifier: 0.0817 (0.0880)  loss_box_reg: 0.0610 (0.0607)  loss_objectness: 0.0299 (0.0366)  loss_rpn_box_reg: 0.0041 (0.0058)  time: 0.7312  data: 0.0174  max mem: 9283
# Epoch: [1] Total time: 0:19:34 (0.7583 s / it)
# Epoch: [2]  [   0/1549]  eta: 1:24:53  lr: 0.002000  loss: 0.1800 (0.1800)  loss_classifier: 0.0701 (0.0701)  loss_box_reg: 0.0328 (0.0328)  loss_objectness: 0.0664 (0.0664)  loss_rpn_box_reg: 0.0107 (0.0107)  time: 3.2886  data: 2.5310  max mem: 9283
# Epoch: [2]  [1000/1549]  eta: 0:06:55  lr: 0.002000  loss: 0.1719 (0.1897)  loss_classifier: 0.0832 (0.0884)  loss_box_reg: 0.0593 (0.0609)  loss_objectness: 0.0247 (0.0350)  loss_rpn_box_reg: 0.0028 (0.0054)  time: 0.7473  data: 0.0174  max mem: 9283
# Epoch: [2]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1759 (0.1899)  loss_classifier: 0.0842 (0.0888)  loss_box_reg: 0.0607 (0.0609)  loss_objectness: 0.0270 (0.0346)  loss_rpn_box_reg: 0.0038 (0.0055)  time: 0.7367  data: 0.0163  max mem: 9283
# Epoch: [2] Total time: 0:19:30 (0.7556 s / it)
# Epoch: [3]  [   0/1549]  eta: 1:11:52  lr: 0.002000  loss: 0.2471 (0.2471)  loss_classifier: 0.0955 (0.0955)  loss_box_reg: 0.0601 (0.0601)  loss_objectness: 0.0827 (0.0827)  loss_rpn_box_reg: 0.0088 (0.0088)  time: 2.7837  data: 1.9901  max mem: 9283
# Epoch: [3]  [1000/1549]  eta: 0:06:55  lr: 0.002000  loss: 0.1895 (0.1901)  loss_classifier: 0.0889 (0.0891)  loss_box_reg: 0.0593 (0.0609)  loss_objectness: 0.0302 (0.0342)  loss_rpn_box_reg: 0.0031 (0.0059)  time: 0.7510  data: 0.0155  max mem: 9283
# Epoch: [3]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1693 (0.1871)  loss_classifier: 0.0836 (0.0883)  loss_box_reg: 0.0625 (0.0604)  loss_objectness: 0.0208 (0.0331)  loss_rpn_box_reg: 0.0034 (0.0053)  time: 0.7408  data: 0.0171  max mem: 9283
# Epoch: [3] Total time: 0:19:31 (0.7566 s / it)
# Epoch: [4]  [   0/1549]  eta: 1:20:24  lr: 0.002000  loss: 0.1904 (0.1904)  loss_classifier: 0.0598 (0.0598)  loss_box_reg: 0.0323 (0.0323)  loss_objectness: 0.0912 (0.0912)  loss_rpn_box_reg: 0.0071 (0.0071)  time: 3.1144  data: 2.2412  max mem: 9283
# Epoch: [4]  [1000/1549]  eta: 0:06:56  lr: 0.002000  loss: 0.1829 (0.1861)  loss_classifier: 0.0758 (0.0865)  loss_box_reg: 0.0613 (0.0608)  loss_objectness: 0.0263 (0.0334)  loss_rpn_box_reg: 0.0034 (0.0054)  time: 0.7553  data: 0.0179  max mem: 9283
# Epoch: [4]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1670 (0.1822)  loss_classifier: 0.0746 (0.0846)  loss_box_reg: 0.0550 (0.0606)  loss_objectness: 0.0309 (0.0318)  loss_rpn_box_reg: 0.0035 (0.0052)  time: 0.7330  data: 0.0160  max mem: 9283
# Epoch: [4] Total time: 0:19:32 (0.7572 s / it)
# Epoch: [5]  [   0/1549]  eta: 1:29:10  lr: 0.002000  loss: 0.1487 (0.1487)  loss_classifier: 0.0688 (0.0688)  loss_box_reg: 0.0541 (0.0541)  loss_objectness: 0.0207 (0.0207)  loss_rpn_box_reg: 0.0052 (0.0052)  time: 3.4543  data: 2.5760  max mem: 9283
# Epoch: [5]  [1000/1549]  eta: 0:06:56  lr: 0.002000  loss: 0.1730 (0.1767)  loss_classifier: 0.0767 (0.0805)  loss_box_reg: 0.0632 (0.0616)  loss_objectness: 0.0239 (0.0298)  loss_rpn_box_reg: 0.0030 (0.0048)  time: 0.7598  data: 0.0177  max mem: 9283
# Epoch: [5]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1652 (0.1763)  loss_classifier: 0.0689 (0.0794)  loss_box_reg: 0.0573 (0.0615)  loss_objectness: 0.0234 (0.0303)  loss_rpn_box_reg: 0.0026 (0.0051)  time: 0.7493  data: 0.0184  max mem: 9283
# Epoch: [5] Total time: 0:19:34 (0.7581 s / it)
# Epoch: [6]  [   0/1549]  eta: 1:17:22  lr: 0.002000  loss: 0.1615 (0.1615)  loss_classifier: 0.0731 (0.0731)  loss_box_reg: 0.0686 (0.0686)  loss_objectness: 0.0175 (0.0175)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 2.9974  data: 2.1002  max mem: 9283
# Epoch: [6]  [1000/1549]  eta: 0:06:56  lr: 0.002000  loss: 0.1728 (0.1763)  loss_classifier: 0.0790 (0.0777)  loss_box_reg: 0.0742 (0.0646)  loss_objectness: 0.0167 (0.0291)  loss_rpn_box_reg: 0.0030 (0.0049)  time: 0.7524  data: 0.0196  max mem: 9283
# Epoch: [6]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1571 (0.1734)  loss_classifier: 0.0770 (0.0762)  loss_box_reg: 0.0647 (0.0632)  loss_objectness: 0.0209 (0.0290)  loss_rpn_box_reg: 0.0031 (0.0050)  time: 0.7400  data: 0.0165  max mem: 9283
# Epoch: [6] Total time: 0:19:32 (0.7569 s / it)
# Epoch: [7]  [   0/1549]  eta: 1:25:46  lr: 0.002000  loss: 0.1427 (0.1427)  loss_classifier: 0.0595 (0.0595)  loss_box_reg: 0.0657 (0.0657)  loss_objectness: 0.0145 (0.0145)  loss_rpn_box_reg: 0.0030 (0.0030)  time: 3.3228  data: 2.4563  max mem: 9283
# Epoch: [7]  [1000/1549]  eta: 0:06:56  lr: 0.002000  loss: 0.1526 (0.1730)  loss_classifier: 0.0679 (0.0756)  loss_box_reg: 0.0531 (0.0647)  loss_objectness: 0.0251 (0.0275)  loss_rpn_box_reg: 0.0034 (0.0052)  time: 0.7525  data: 0.0189  max mem: 9283
# Epoch: [7]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1715 (0.1733)  loss_classifier: 0.0691 (0.0759)  loss_box_reg: 0.0646 (0.0652)  loss_objectness: 0.0278 (0.0273)  loss_rpn_box_reg: 0.0031 (0.0049)  time: 0.7344  data: 0.0157  max mem: 9283
# Epoch: [7] Total time: 0:19:33 (0.7574 s / it)
# Epoch: [8]  [   0/1549]  eta: 1:20:42  lr: 0.002000  loss: 0.1639 (0.1639)  loss_classifier: 0.0824 (0.0824)  loss_box_reg: 0.0532 (0.0532)  loss_objectness: 0.0254 (0.0254)  loss_rpn_box_reg: 0.0030 (0.0030)  time: 3.1262  data: 2.2369  max mem: 9283
# Epoch: [8]  [1000/1549]  eta: 0:06:55  lr: 0.002000  loss: 0.1699 (0.1710)  loss_classifier: 0.0760 (0.0737)  loss_box_reg: 0.0698 (0.0660)  loss_objectness: 0.0257 (0.0267)  loss_rpn_box_reg: 0.0041 (0.0046)  time: 0.7601  data: 0.0184  max mem: 9283
# Epoch: [8]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1746 (0.1716)  loss_classifier: 0.0715 (0.0741)  loss_box_reg: 0.0648 (0.0662)  loss_objectness: 0.0237 (0.0266)  loss_rpn_box_reg: 0.0040 (0.0048)  time: 0.7522  data: 0.0174  max mem: 9283
# Epoch: [8] Total time: 0:19:32 (0.7567 s / it)
# Epoch: [9]  [   0/1549]  eta: 1:07:06  lr: 0.002000  loss: 0.1405 (0.1405)  loss_classifier: 0.0685 (0.0685)  loss_box_reg: 0.0496 (0.0496)  loss_objectness: 0.0191 (0.0191)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 2.5996  data: 1.8054  max mem: 9283
# Epoch: [9]  [1000/1549]  eta: 0:06:55  lr: 0.002000  loss: 0.1778 (0.1718)  loss_classifier: 0.0723 (0.0744)  loss_box_reg: 0.0709 (0.0670)  loss_objectness: 0.0142 (0.0257)  loss_rpn_box_reg: 0.0030 (0.0047)  time: 0.7575  data: 0.0170  max mem: 9283
# Epoch: [9]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1626 (0.1720)  loss_classifier: 0.0694 (0.0744)  loss_box_reg: 0.0639 (0.0675)  loss_objectness: 0.0228 (0.0254)  loss_rpn_box_reg: 0.0032 (0.0047)  time: 0.7352  data: 0.0175  max mem: 9283
# Epoch: [9] Total time: 0:19:33 (0.7578 s / it)
# Epoch: [10]  [   0/1549]  eta: 1:17:30  lr: 0.002000  loss: 0.1261 (0.1261)  loss_classifier: 0.0635 (0.0635)  loss_box_reg: 0.0375 (0.0375)  loss_objectness: 0.0228 (0.0228)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 3.0024  data: 2.1811  max mem: 9283
# Epoch: [10]  [1000/1549]  eta: 0:06:54  lr: 0.002000  loss: 0.1479 (0.1744)  loss_classifier: 0.0639 (0.0752)  loss_box_reg: 0.0630 (0.0686)  loss_objectness: 0.0130 (0.0255)  loss_rpn_box_reg: 0.0026 (0.0051)  time: 0.7511  data: 0.0167  max mem: 9283
# Epoch: [10]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1715 (0.1713)  loss_classifier: 0.0766 (0.0741)  loss_box_reg: 0.0645 (0.0679)  loss_objectness: 0.0251 (0.0247)  loss_rpn_box_reg: 0.0032 (0.0047)  time: 0.7292  data: 0.0157  max mem: 9283
# Epoch: [10] Total time: 0:19:27 (0.7537 s / it)
# creating index...
# index created!
# Test:  [  0/368]  eta: 0:15:40  model_time: 0.2550 (0.2550)  evaluator_time: 0.0089 (0.0089)  time: 2.5565  data: 2.2818  max mem: 9283
# Test:  [100/368]  eta: 0:01:19  model_time: 0.2460 (0.2483)  evaluator_time: 0.0040 (0.0050)  time: 0.2722  data: 0.0143  max mem: 9283
# Test:  [200/368]  eta: 0:00:48  model_time: 0.2464 (0.2474)  evaluator_time: 0.0040 (0.0048)  time: 0.2744  data: 0.0152  max mem: 9283
# Test:  [300/368]  eta: 0:00:19  model_time: 0.2463 (0.2475)  evaluator_time: 0.0046 (0.0048)  time: 0.2767  data: 0.0176  max mem: 9283
# Test:  [367/368]  eta: 0:00:00  model_time: 0.2451 (0.2471)  evaluator_time: 0.0040 (0.0047)  time: 0.2676  data: 0.0153  max mem: 9283
# Test: Total time: 0:01:43 (0.2822 s / it)
# Averaged stats: model_time: 0.2451 (0.2471)  evaluator_time: 0.0040 (0.0047)
# Accumulating evaluation results...
# DONE (t=0.39s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.178
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.134
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.161
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.275
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.458
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.406
# Epoch: [11]  [   0/1549]  eta: 1:18:30  lr: 0.002000  loss: 0.1718 (0.1718)  loss_classifier: 0.0758 (0.0758)  loss_box_reg: 0.0572 (0.0572)  loss_objectness: 0.0351 (0.0351)  loss_rpn_box_reg: 0.0037 (0.0037)  time: 3.0411  data: 2.2028  max mem: 9283
# Epoch: [11]  [1000/1549]  eta: 0:06:55  lr: 0.002000  loss: 0.1700 (0.1677)  loss_classifier: 0.0690 (0.0721)  loss_box_reg: 0.0725 (0.0670)  loss_objectness: 0.0155 (0.0240)  loss_rpn_box_reg: 0.0035 (0.0046)  time: 0.7557  data: 0.0198  max mem: 9283
# Epoch: [11]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1604 (0.1693)  loss_classifier: 0.0692 (0.0726)  loss_box_reg: 0.0672 (0.0680)  loss_objectness: 0.0142 (0.0243)  loss_rpn_box_reg: 0.0028 (0.0045)  time: 0.7437  data: 0.0168  max mem: 9283
# Epoch: [11] Total time: 0:19:32 (0.7567 s / it)
# Epoch: [12]  [   0/1549]  eta: 1:25:05  lr: 0.002000  loss: 0.1504 (0.1504)  loss_classifier: 0.0617 (0.0617)  loss_box_reg: 0.0418 (0.0418)  loss_objectness: 0.0406 (0.0406)  loss_rpn_box_reg: 0.0063 (0.0063)  time: 3.2958  data: 2.4309  max mem: 9283
# Epoch: [12]  [1000/1549]  eta: 0:06:56  lr: 0.002000  loss: 0.1674 (0.1712)  loss_classifier: 0.0697 (0.0727)  loss_box_reg: 0.0710 (0.0692)  loss_objectness: 0.0172 (0.0243)  loss_rpn_box_reg: 0.0024 (0.0050)  time: 0.7586  data: 0.0183  max mem: 9283
# Epoch: [12]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1631 (0.1692)  loss_classifier: 0.0769 (0.0725)  loss_box_reg: 0.0626 (0.0686)  loss_objectness: 0.0185 (0.0234)  loss_rpn_box_reg: 0.0025 (0.0046)  time: 0.7373  data: 0.0169  max mem: 9283
# Epoch: [12] Total time: 0:19:32 (0.7567 s / it)
# Epoch: [13]  [   0/1549]  eta: 1:17:53  lr: 0.002000  loss: 0.1936 (0.1936)  loss_classifier: 0.0990 (0.0990)  loss_box_reg: 0.0767 (0.0767)  loss_objectness: 0.0156 (0.0156)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 3.0168  data: 2.1810  max mem: 9283
# Epoch: [13]  [1000/1549]  eta: 0:06:56  lr: 0.002000  loss: 0.1581 (0.1686)  loss_classifier: 0.0646 (0.0717)  loss_box_reg: 0.0676 (0.0678)  loss_objectness: 0.0167 (0.0243)  loss_rpn_box_reg: 0.0025 (0.0049)  time: 0.7612  data: 0.0196  max mem: 9283
# Epoch: [13]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1692 (0.1675)  loss_classifier: 0.0825 (0.0718)  loss_box_reg: 0.0722 (0.0681)  loss_objectness: 0.0105 (0.0231)  loss_rpn_box_reg: 0.0029 (0.0045)  time: 0.7411  data: 0.0180  max mem: 9283
# Epoch: [13] Total time: 0:19:34 (0.7583 s / it)
# Epoch: [14]  [   0/1549]  eta: 1:12:02  lr: 0.002000  loss: 0.1652 (0.1652)  loss_classifier: 0.0674 (0.0674)  loss_box_reg: 0.0694 (0.0694)  loss_objectness: 0.0248 (0.0248)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 2.7903  data: 1.9203  max mem: 9283
# Epoch: [14]  [1000/1549]  eta: 0:06:56  lr: 0.002000  loss: 0.1640 (0.1699)  loss_classifier: 0.0699 (0.0720)  loss_box_reg: 0.0682 (0.0694)  loss_objectness: 0.0168 (0.0238)  loss_rpn_box_reg: 0.0033 (0.0048)  time: 0.7556  data: 0.0164  max mem: 9283
# Epoch: [14]  [1548/1549]  eta: 0:00:00  lr: 0.002000  loss: 0.1784 (0.1683)  loss_classifier: 0.0736 (0.0721)  loss_box_reg: 0.0660 (0.0694)  loss_objectness: 0.0149 (0.0224)  loss_rpn_box_reg: 0.0027 (0.0044)  time: 0.7381  data: 0.0145  max mem: 9283
# Epoch: [14] Total time: 0:19:33 (0.7574 s / it)
# Epoch: [15]  [   0/1549]  eta: 1:18:12  lr: 0.001000  loss: 0.1604 (0.1604)  loss_classifier: 0.0764 (0.0764)  loss_box_reg: 0.0702 (0.0702)  loss_objectness: 0.0101 (0.0101)  loss_rpn_box_reg: 0.0037 (0.0037)  time: 3.0292  data: 2.1924  max mem: 9283
# Epoch: [15]  [1000/1549]  eta: 0:06:56  lr: 0.001000  loss: 0.1633 (0.1665)  loss_classifier: 0.0791 (0.0721)  loss_box_reg: 0.0655 (0.0710)  loss_objectness: 0.0164 (0.0197)  loss_rpn_box_reg: 0.0027 (0.0036)  time: 0.7530  data: 0.0178  max mem: 9283
# Epoch: [15]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1372 (0.1670)  loss_classifier: 0.0631 (0.0712)  loss_box_reg: 0.0562 (0.0701)  loss_objectness: 0.0127 (0.0214)  loss_rpn_box_reg: 0.0029 (0.0044)  time: 0.7373  data: 0.0173  max mem: 9283
# Epoch: [15] Total time: 0:19:32 (0.7572 s / it)
# creating index...
# index created!
# Test:  [  0/368]  eta: 0:13:29  model_time: 0.2583 (0.2583)  evaluator_time: 0.0236 (0.0236)  time: 2.1990  data: 1.9073  max mem: 9283
# Test:  [100/368]  eta: 0:01:19  model_time: 0.2472 (0.2495)  evaluator_time: 0.0040 (0.0046)  time: 0.2779  data: 0.0155  max mem: 9283
# Test:  [200/368]  eta: 0:00:48  model_time: 0.2474 (0.2491)  evaluator_time: 0.0037 (0.0046)  time: 0.2816  data: 0.0201  max mem: 9283
# Test:  [300/368]  eta: 0:00:19  model_time: 0.2470 (0.2490)  evaluator_time: 0.0037 (0.0045)  time: 0.2769  data: 0.0164  max mem: 9283
# Test:  [367/368]  eta: 0:00:00  model_time: 0.2457 (0.2485)  evaluator_time: 0.0036 (0.0044)  time: 0.2676  data: 0.0149  max mem: 9283
# Test: Total time: 0:01:44 (0.2839 s / it)
# Averaged stats: model_time: 0.2457 (0.2485)  evaluator_time: 0.0036 (0.0044)
# Accumulating evaluation results...
# DONE (t=0.49s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.418
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.079
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.218
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.313
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.488
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.501
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.509
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.454
# Epoch: [16]  [   0/1549]  eta: 1:21:30  lr: 0.001000  loss: 0.1460 (0.1460)  loss_classifier: 0.0603 (0.0603)  loss_box_reg: 0.0710 (0.0710)  loss_objectness: 0.0117 (0.0117)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 3.1574  data: 2.2949  max mem: 9283
# Epoch: [16]  [1000/1549]  eta: 0:06:56  lr: 0.001000  loss: 0.1537 (0.1662)  loss_classifier: 0.0630 (0.0707)  loss_box_reg: 0.0717 (0.0697)  loss_objectness: 0.0140 (0.0214)  loss_rpn_box_reg: 0.0027 (0.0044)  time: 0.7525  data: 0.0186  max mem: 9283
# Epoch: [16]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1626 (0.1657)  loss_classifier: 0.0714 (0.0708)  loss_box_reg: 0.0624 (0.0697)  loss_objectness: 0.0203 (0.0209)  loss_rpn_box_reg: 0.0038 (0.0043)  time: 0.7369  data: 0.0150  max mem: 9283
# Epoch: [16] Total time: 0:19:33 (0.7574 s / it)
# Epoch: [17]  [   0/1549]  eta: 1:18:18  lr: 0.001000  loss: 0.1576 (0.1576)  loss_classifier: 0.0639 (0.0639)  loss_box_reg: 0.0449 (0.0449)  loss_objectness: 0.0450 (0.0450)  loss_rpn_box_reg: 0.0039 (0.0039)  time: 3.0329  data: 2.1727  max mem: 9283
# Epoch: [17]  [1000/1549]  eta: 0:06:54  lr: 0.001000  loss: 0.1514 (0.1630)  loss_classifier: 0.0625 (0.0702)  loss_box_reg: 0.0707 (0.0692)  loss_objectness: 0.0165 (0.0200)  loss_rpn_box_reg: 0.0030 (0.0037)  time: 0.7538  data: 0.0178  max mem: 9283
# Epoch: [17]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1563 (0.1647)  loss_classifier: 0.0561 (0.0703)  loss_box_reg: 0.0635 (0.0697)  loss_objectness: 0.0164 (0.0206)  loss_rpn_box_reg: 0.0027 (0.0042)  time: 0.7417  data: 0.0154  max mem: 9283
# Epoch: [17] Total time: 0:19:29 (0.7548 s / it)
# Epoch: [18]  [   0/1549]  eta: 1:24:53  lr: 0.001000  loss: 0.2815 (0.2815)  loss_classifier: 0.1299 (0.1299)  loss_box_reg: 0.1202 (0.1202)  loss_objectness: 0.0235 (0.0235)  loss_rpn_box_reg: 0.0079 (0.0079)  time: 3.2885  data: 2.4457  max mem: 9283
# Epoch: [18]  [1000/1549]  eta: 0:06:55  lr: 0.001000  loss: 0.1480 (0.1639)  loss_classifier: 0.0615 (0.0694)  loss_box_reg: 0.0628 (0.0691)  loss_objectness: 0.0164 (0.0209)  loss_rpn_box_reg: 0.0023 (0.0044)  time: 0.7584  data: 0.0186  max mem: 9283
# Epoch: [18]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1506 (0.1621)  loss_classifier: 0.0693 (0.0688)  loss_box_reg: 0.0713 (0.0687)  loss_objectness: 0.0099 (0.0203)  loss_rpn_box_reg: 0.0023 (0.0042)  time: 0.7336  data: 0.0155  max mem: 9283
# Epoch: [18] Total time: 0:19:32 (0.7569 s / it)
# Epoch: [19]  [   0/1549]  eta: 1:25:46  lr: 0.001000  loss: 0.1211 (0.1211)  loss_classifier: 0.0445 (0.0445)  loss_box_reg: 0.0626 (0.0626)  loss_objectness: 0.0119 (0.0119)  loss_rpn_box_reg: 0.0021 (0.0021)  time: 3.3225  data: 2.3909  max mem: 9283
# Epoch: [19]  [1000/1549]  eta: 0:06:56  lr: 0.001000  loss: 0.1445 (0.1605)  loss_classifier: 0.0548 (0.0694)  loss_box_reg: 0.0607 (0.0690)  loss_objectness: 0.0126 (0.0186)  loss_rpn_box_reg: 0.0026 (0.0035)  time: 0.7515  data: 0.0210  max mem: 9283
# Epoch: [19]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1500 (0.1622)  loss_classifier: 0.0584 (0.0689)  loss_box_reg: 0.0638 (0.0690)  loss_objectness: 0.0182 (0.0201)  loss_rpn_box_reg: 0.0025 (0.0041)  time: 0.7422  data: 0.0169  max mem: 9283
# Epoch: [19] Total time: 0:19:32 (0.7571 s / it)
# Epoch: [20]  [   0/1549]  eta: 1:10:42  lr: 0.001000  loss: 0.1719 (0.1719)  loss_classifier: 0.0841 (0.0841)  loss_box_reg: 0.0610 (0.0610)  loss_objectness: 0.0243 (0.0243)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 2.7386  data: 1.8871  max mem: 9283
# Epoch: [20]  [1000/1549]  eta: 0:06:55  lr: 0.001000  loss: 0.1552 (0.1606)  loss_classifier: 0.0611 (0.0679)  loss_box_reg: 0.0678 (0.0683)  loss_objectness: 0.0130 (0.0203)  loss_rpn_box_reg: 0.0030 (0.0041)  time: 0.7470  data: 0.0177  max mem: 9283
# Epoch: [20]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1683 (0.1613)  loss_classifier: 0.0717 (0.0683)  loss_box_reg: 0.0721 (0.0686)  loss_objectness: 0.0149 (0.0203)  loss_rpn_box_reg: 0.0024 (0.0042)  time: 0.7418  data: 0.0196  max mem: 9283
# Epoch: [20] Total time: 0:19:31 (0.7560 s / it)
# creating index...
# index created!
# Test:  [  0/368]  eta: 0:17:53  model_time: 0.3087 (0.3087)  evaluator_time: 0.0072 (0.0072)  time: 2.9164  data: 2.5914  max mem: 9283
# Test:  [100/368]  eta: 0:01:21  model_time: 0.2468 (0.2503)  evaluator_time: 0.0044 (0.0052)  time: 0.2763  data: 0.0151  max mem: 9283
# Test:  [200/368]  eta: 0:00:48  model_time: 0.2465 (0.2489)  evaluator_time: 0.0041 (0.0051)  time: 0.2794  data: 0.0164  max mem: 9283
# Test:  [300/368]  eta: 0:00:19  model_time: 0.2475 (0.2487)  evaluator_time: 0.0043 (0.0050)  time: 0.2760  data: 0.0155  max mem: 9283
# Test:  [367/368]  eta: 0:00:00  model_time: 0.2462 (0.2483)  evaluator_time: 0.0040 (0.0050)  time: 0.2723  data: 0.0169  max mem: 9283
# Test: Total time: 0:01:45 (0.2860 s / it)
# Averaged stats: model_time: 0.2462 (0.2483)  evaluator_time: 0.0040 (0.0050)
# Accumulating evaluation results...
# DONE (t=0.43s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.233
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.451
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.232
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.234
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.248
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.514
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.466
# Epoch: [21]  [   0/1549]  eta: 1:19:05  lr: 0.001000  loss: 0.1663 (0.1663)  loss_classifier: 0.0682 (0.0682)  loss_box_reg: 0.0922 (0.0922)  loss_objectness: 0.0042 (0.0042)  loss_rpn_box_reg: 0.0017 (0.0017)  time: 3.0639  data: 2.2311  max mem: 9283
# Epoch: [21]  [1000/1549]  eta: 0:06:57  lr: 0.001000  loss: 0.1511 (0.1606)  loss_classifier: 0.0644 (0.0690)  loss_box_reg: 0.0757 (0.0689)  loss_objectness: 0.0084 (0.0188)  loss_rpn_box_reg: 0.0027 (0.0039)  time: 0.7641  data: 0.0208  max mem: 9283
# Epoch: [21]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1570 (0.1613)  loss_classifier: 0.0695 (0.0685)  loss_box_reg: 0.0713 (0.0688)  loss_objectness: 0.0133 (0.0199)  loss_rpn_box_reg: 0.0023 (0.0041)  time: 0.7358  data: 0.0181  max mem: 9283
# Epoch: [21] Total time: 0:19:35 (0.7588 s / it)
# Epoch: [22]  [   0/1549]  eta: 1:16:43  lr: 0.001000  loss: 0.2036 (0.2036)  loss_classifier: 0.0962 (0.0962)  loss_box_reg: 0.0931 (0.0931)  loss_objectness: 0.0108 (0.0108)  loss_rpn_box_reg: 0.0035 (0.0035)  time: 2.9721  data: 2.0891  max mem: 9283
# Epoch: [22]  [1000/1549]  eta: 0:06:55  lr: 0.001000  loss: 0.1570 (0.1604)  loss_classifier: 0.0662 (0.0673)  loss_box_reg: 0.0743 (0.0684)  loss_objectness: 0.0098 (0.0202)  loss_rpn_box_reg: 0.0023 (0.0046)  time: 0.7502  data: 0.0185  max mem: 9283
# Epoch: [22]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1531 (0.1604)  loss_classifier: 0.0616 (0.0678)  loss_box_reg: 0.0659 (0.0689)  loss_objectness: 0.0127 (0.0195)  loss_rpn_box_reg: 0.0027 (0.0042)  time: 0.7394  data: 0.0196  max mem: 9283
# Epoch: [22] Total time: 0:19:31 (0.7565 s / it)
# Epoch: [23]  [   0/1549]  eta: 1:47:26  lr: 0.001000  loss: 0.1424 (0.1424)  loss_classifier: 0.0690 (0.0690)  loss_box_reg: 0.0628 (0.0628)  loss_objectness: 0.0091 (0.0091)  loss_rpn_box_reg: 0.0015 (0.0015)  time: 4.1615  data: 3.2342  max mem: 9283
# Epoch: [23]  [1000/1549]  eta: 0:06:56  lr: 0.001000  loss: 0.1618 (0.1613)  loss_classifier: 0.0740 (0.0686)  loss_box_reg: 0.0699 (0.0696)  loss_objectness: 0.0137 (0.0192)  loss_rpn_box_reg: 0.0026 (0.0039)  time: 0.7519  data: 0.0214  max mem: 9283
# Epoch: [23]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1745 (0.1612)  loss_classifier: 0.0664 (0.0683)  loss_box_reg: 0.0731 (0.0694)  loss_objectness: 0.0196 (0.0193)  loss_rpn_box_reg: 0.0026 (0.0042)  time: 0.7364  data: 0.0177  max mem: 9283
# Epoch: [23] Total time: 0:19:32 (0.7569 s / it)
# Epoch: [24]  [   0/1549]  eta: 1:23:53  lr: 0.001000  loss: 0.1785 (0.1785)  loss_classifier: 0.0739 (0.0739)  loss_box_reg: 0.0921 (0.0921)  loss_objectness: 0.0098 (0.0098)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 3.2495  data: 2.3963  max mem: 9283
# Epoch: [24]  [1000/1549]  eta: 0:06:55  lr: 0.001000  loss: 0.1400 (0.1603)  loss_classifier: 0.0601 (0.0673)  loss_box_reg: 0.0679 (0.0688)  loss_objectness: 0.0139 (0.0197)  loss_rpn_box_reg: 0.0028 (0.0044)  time: 0.7445  data: 0.0171  max mem: 9283
# Epoch: [24]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1599 (0.1600)  loss_classifier: 0.0649 (0.0674)  loss_box_reg: 0.0648 (0.0690)  loss_objectness: 0.0185 (0.0194)  loss_rpn_box_reg: 0.0030 (0.0042)  time: 0.7359  data: 0.0158  max mem: 9283
# Epoch: [24] Total time: 0:19:28 (0.7546 s / it)
# Epoch: [25]  [   0/1549]  eta: 1:27:24  lr: 0.001000  loss: 0.1413 (0.1413)  loss_classifier: 0.0711 (0.0711)  loss_box_reg: 0.0565 (0.0565)  loss_objectness: 0.0111 (0.0111)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 3.3855  data: 2.6354  max mem: 9283
# Epoch: [25]  [1000/1549]  eta: 0:06:56  lr: 0.001000  loss: 0.1481 (0.1605)  loss_classifier: 0.0614 (0.0683)  loss_box_reg: 0.0677 (0.0697)  loss_objectness: 0.0137 (0.0184)  loss_rpn_box_reg: 0.0032 (0.0042)  time: 0.7551  data: 0.0189  max mem: 9283
# Epoch: [25]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1423 (0.1598)  loss_classifier: 0.0591 (0.0677)  loss_box_reg: 0.0702 (0.0692)  loss_objectness: 0.0126 (0.0188)  loss_rpn_box_reg: 0.0024 (0.0041)  time: 0.7367  data: 0.0190  max mem: 9283
# Epoch: [25] Total time: 0:19:31 (0.7564 s / it)
# creating index...
# index created!
# Test:  [  0/368]  eta: 0:13:46  model_time: 0.2692 (0.2692)  evaluator_time: 0.0057 (0.0057)  time: 2.2472  data: 1.9646  max mem: 9283
# Test:  [100/368]  eta: 0:01:19  model_time: 0.2453 (0.2480)  evaluator_time: 0.0036 (0.0039)  time: 0.2744  data: 0.0154  max mem: 9283
# Test:  [200/368]  eta: 0:00:48  model_time: 0.2475 (0.2478)  evaluator_time: 0.0038 (0.0040)  time: 0.2798  data: 0.0175  max mem: 9283
# Test:  [300/368]  eta: 0:00:19  model_time: 0.2459 (0.2477)  evaluator_time: 0.0032 (0.0039)  time: 0.2764  data: 0.0157  max mem: 9283
# Test:  [367/368]  eta: 0:00:00  model_time: 0.2468 (0.2474)  evaluator_time: 0.0036 (0.0039)  time: 0.2698  data: 0.0162  max mem: 9283
# Test: Total time: 0:01:44 (0.2838 s / it)
# Averaged stats: model_time: 0.2468 (0.2474)  evaluator_time: 0.0036 (0.0039)
# Accumulating evaluation results...
# DONE (t=0.34s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.248
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.344
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.501
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.448
# Epoch: [26]  [   0/1549]  eta: 1:23:18  lr: 0.001000  loss: 0.1220 (0.1220)  loss_classifier: 0.0587 (0.0587)  loss_box_reg: 0.0496 (0.0496)  loss_objectness: 0.0089 (0.0089)  loss_rpn_box_reg: 0.0048 (0.0048)  time: 3.2267  data: 2.3811  max mem: 9283
# Epoch: [26]  [1000/1549]  eta: 0:06:56  lr: 0.001000  loss: 0.1644 (0.1595)  loss_classifier: 0.0622 (0.0670)  loss_box_reg: 0.0648 (0.0686)  loss_objectness: 0.0131 (0.0194)  loss_rpn_box_reg: 0.0036 (0.0045)  time: 0.7413  data: 0.0163  max mem: 9283
# Epoch: [26]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1482 (0.1589)  loss_classifier: 0.0646 (0.0669)  loss_box_reg: 0.0650 (0.0690)  loss_objectness: 0.0099 (0.0189)  loss_rpn_box_reg: 0.0025 (0.0042)  time: 0.7371  data: 0.0177  max mem: 9283
# Epoch: [26] Total time: 0:19:32 (0.7572 s / it)
# Epoch: [27]  [   0/1549]  eta: 1:33:18  lr: 0.001000  loss: 0.1920 (0.1920)  loss_classifier: 0.0649 (0.0649)  loss_box_reg: 0.0995 (0.0995)  loss_objectness: 0.0211 (0.0211)  loss_rpn_box_reg: 0.0065 (0.0065)  time: 3.6142  data: 2.7066  max mem: 9283
# Epoch: [27]  [1000/1549]  eta: 0:06:56  lr: 0.001000  loss: 0.1572 (0.1610)  loss_classifier: 0.0673 (0.0674)  loss_box_reg: 0.0641 (0.0696)  loss_objectness: 0.0175 (0.0195)  loss_rpn_box_reg: 0.0029 (0.0044)  time: 0.7622  data: 0.0210  max mem: 9283
# Epoch: [27]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1583 (0.1596)  loss_classifier: 0.0707 (0.0675)  loss_box_reg: 0.0708 (0.0696)  loss_objectness: 0.0110 (0.0184)  loss_rpn_box_reg: 0.0022 (0.0040)  time: 0.7342  data: 0.0175  max mem: 9283
# Epoch: [27] Total time: 0:19:32 (0.7568 s / it)
# Epoch: [28]  [   0/1549]  eta: 1:19:12  lr: 0.001000  loss: 0.1418 (0.1418)  loss_classifier: 0.0734 (0.0734)  loss_box_reg: 0.0590 (0.0590)  loss_objectness: 0.0063 (0.0063)  loss_rpn_box_reg: 0.0030 (0.0030)  time: 3.0680  data: 2.2148  max mem: 9283
# Epoch: [28]  [1000/1549]  eta: 0:06:55  lr: 0.001000  loss: 0.1719 (0.1580)  loss_classifier: 0.0681 (0.0664)  loss_box_reg: 0.0731 (0.0687)  loss_objectness: 0.0143 (0.0187)  loss_rpn_box_reg: 0.0038 (0.0042)  time: 0.7590  data: 0.0182  max mem: 9283
# Epoch: [28]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1605 (0.1573)  loss_classifier: 0.0682 (0.0665)  loss_box_reg: 0.0661 (0.0687)  loss_objectness: 0.0097 (0.0181)  loss_rpn_box_reg: 0.0026 (0.0040)  time: 0.7352  data: 0.0159  max mem: 9283
# Epoch: [28] Total time: 0:19:31 (0.7564 s / it)
# Epoch: [29]  [   0/1549]  eta: 1:22:12  lr: 0.001000  loss: 0.1370 (0.1370)  loss_classifier: 0.0650 (0.0650)  loss_box_reg: 0.0649 (0.0649)  loss_objectness: 0.0046 (0.0046)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 3.1844  data: 2.2669  max mem: 9283
# Epoch: [29]  [1000/1549]  eta: 0:06:56  lr: 0.001000  loss: 0.1622 (0.1566)  loss_classifier: 0.0590 (0.0660)  loss_box_reg: 0.0717 (0.0679)  loss_objectness: 0.0172 (0.0188)  loss_rpn_box_reg: 0.0031 (0.0039)  time: 0.7465  data: 0.0177  max mem: 9283
# Epoch: [29]  [1548/1549]  eta: 0:00:00  lr: 0.001000  loss: 0.1423 (0.1572)  loss_classifier: 0.0612 (0.0663)  loss_box_reg: 0.0616 (0.0688)  loss_objectness: 0.0096 (0.0181)  loss_rpn_box_reg: 0.0026 (0.0041)  time: 0.7326  data: 0.0156  max mem: 9283
# Epoch: [29] Total time: 0:19:31 (0.7565 s / it)
# Epoch: [30]  [   0/1549]  eta: 1:28:44  lr: 0.000500  loss: 0.1255 (0.1255)  loss_classifier: 0.0307 (0.0307)  loss_box_reg: 0.0708 (0.0708)  loss_objectness: 0.0176 (0.0176)  loss_rpn_box_reg: 0.0064 (0.0064)  time: 3.4377  data: 2.6000  max mem: 9283
# Epoch: [30]  [1000/1549]  eta: 0:06:55  lr: 0.000500  loss: 0.1491 (0.1554)  loss_classifier: 0.0612 (0.0653)  loss_box_reg: 0.0707 (0.0687)  loss_objectness: 0.0157 (0.0175)  loss_rpn_box_reg: 0.0028 (0.0039)  time: 0.7514  data: 0.0182  max mem: 9283
# Epoch: [30]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1385 (0.1554)  loss_classifier: 0.0569 (0.0657)  loss_box_reg: 0.0638 (0.0687)  loss_objectness: 0.0110 (0.0172)  loss_rpn_box_reg: 0.0032 (0.0039)  time: 0.7393  data: 0.0161  max mem: 9283
# Epoch: [30] Total time: 0:19:31 (0.7564 s / it)
# creating index...
# index created!
# Test:  [  0/368]  eta: 0:14:17  model_time: 0.2477 (0.2477)  evaluator_time: 0.0072 (0.0072)  time: 2.3308  data: 2.0682  max mem: 9283
# Test:  [100/368]  eta: 0:01:20  model_time: 0.2452 (0.2472)  evaluator_time: 0.0044 (0.0044)  time: 0.2794  data: 0.0176  max mem: 9283
# Test:  [200/368]  eta: 0:00:48  model_time: 0.2465 (0.2471)  evaluator_time: 0.0042 (0.0045)  time: 0.2813  data: 0.0189  max mem: 9283
# Test:  [300/368]  eta: 0:00:19  model_time: 0.2461 (0.2472)  evaluator_time: 0.0037 (0.0044)  time: 0.2762  data: 0.0166  max mem: 9283
# Test:  [367/368]  eta: 0:00:00  model_time: 0.2454 (0.2468)  evaluator_time: 0.0038 (0.0044)  time: 0.2656  data: 0.0139  max mem: 9283
# Test: Total time: 0:01:44 (0.2841 s / it)
# Averaged stats: model_time: 0.2454 (0.2468)  evaluator_time: 0.0038 (0.0044)
# Accumulating evaluation results...
# DONE (t=0.40s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.267
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.497
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.273
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.359
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.535
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.544
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.492
# Epoch: [31]  [   0/1549]  eta: 1:29:58  lr: 0.000500  loss: 0.1813 (0.1813)  loss_classifier: 0.0735 (0.0735)  loss_box_reg: 0.0876 (0.0876)  loss_objectness: 0.0140 (0.0140)  loss_rpn_box_reg: 0.0062 (0.0062)  time: 3.4853  data: 2.6549  max mem: 9283
# Epoch: [31]  [1000/1549]  eta: 0:06:55  lr: 0.000500  loss: 0.1671 (0.1542)  loss_classifier: 0.0712 (0.0650)  loss_box_reg: 0.0766 (0.0693)  loss_objectness: 0.0130 (0.0161)  loss_rpn_box_reg: 0.0029 (0.0037)  time: 0.7718  data: 0.0213  max mem: 9283
# Epoch: [31]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1561 (0.1552)  loss_classifier: 0.0644 (0.0654)  loss_box_reg: 0.0648 (0.0688)  loss_objectness: 0.0100 (0.0171)  loss_rpn_box_reg: 0.0027 (0.0039)  time: 0.7355  data: 0.0173  max mem: 9283
# Epoch: [31] Total time: 0:19:29 (0.7551 s / it)
# Epoch: [32]  [   0/1549]  eta: 1:13:59  lr: 0.000500  loss: 0.1632 (0.1632)  loss_classifier: 0.0590 (0.0590)  loss_box_reg: 0.0942 (0.0942)  loss_objectness: 0.0085 (0.0085)  loss_rpn_box_reg: 0.0017 (0.0017)  time: 2.8660  data: 2.1039  max mem: 9283
# Epoch: [32]  [1000/1549]  eta: 0:06:56  lr: 0.000500  loss: 0.1548 (0.1544)  loss_classifier: 0.0653 (0.0645)  loss_box_reg: 0.0699 (0.0680)  loss_objectness: 0.0140 (0.0177)  loss_rpn_box_reg: 0.0024 (0.0041)  time: 0.7528  data: 0.0178  max mem: 9283
# Epoch: [32]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1461 (0.1536)  loss_classifier: 0.0611 (0.0645)  loss_box_reg: 0.0613 (0.0685)  loss_objectness: 0.0136 (0.0168)  loss_rpn_box_reg: 0.0025 (0.0039)  time: 0.7417  data: 0.0180  max mem: 9283
# Epoch: [32] Total time: 0:19:33 (0.7575 s / it)
# Epoch: [33]  [   0/1549]  eta: 1:26:19  lr: 0.000500  loss: 0.1664 (0.1664)  loss_classifier: 0.0896 (0.0896)  loss_box_reg: 0.0694 (0.0694)  loss_objectness: 0.0061 (0.0061)  loss_rpn_box_reg: 0.0014 (0.0014)  time: 3.3440  data: 2.5101  max mem: 9283
# Epoch: [33]  [1000/1549]  eta: 0:06:56  lr: 0.000500  loss: 0.1502 (0.1555)  loss_classifier: 0.0632 (0.0658)  loss_box_reg: 0.0712 (0.0692)  loss_objectness: 0.0146 (0.0169)  loss_rpn_box_reg: 0.0032 (0.0036)  time: 0.7681  data: 0.0232  max mem: 9283
# Epoch: [33]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1562 (0.1553)  loss_classifier: 0.0649 (0.0656)  loss_box_reg: 0.0721 (0.0692)  loss_objectness: 0.0090 (0.0167)  loss_rpn_box_reg: 0.0027 (0.0039)  time: 0.7386  data: 0.0170  max mem: 9283
# Epoch: [33] Total time: 0:19:34 (0.7581 s / it)
# Epoch: [34]  [   0/1549]  eta: 1:27:05  lr: 0.000500  loss: 0.1323 (0.1323)  loss_classifier: 0.0458 (0.0458)  loss_box_reg: 0.0753 (0.0753)  loss_objectness: 0.0079 (0.0079)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 3.3737  data: 2.5538  max mem: 9283
# Epoch: [34]  [1000/1549]  eta: 0:06:56  lr: 0.000500  loss: 0.1497 (0.1528)  loss_classifier: 0.0612 (0.0651)  loss_box_reg: 0.0660 (0.0683)  loss_objectness: 0.0112 (0.0160)  loss_rpn_box_reg: 0.0028 (0.0035)  time: 0.7573  data: 0.0174  max mem: 9283
# Epoch: [34]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1466 (0.1536)  loss_classifier: 0.0631 (0.0648)  loss_box_reg: 0.0673 (0.0684)  loss_objectness: 0.0123 (0.0166)  loss_rpn_box_reg: 0.0031 (0.0039)  time: 0.7292  data: 0.0166  max mem: 9283
# Epoch: [34] Total time: 0:19:32 (0.7569 s / it)
# Epoch: [35]  [   0/1549]  eta: 1:14:07  lr: 0.000500  loss: 0.1796 (0.1796)  loss_classifier: 0.0717 (0.0717)  loss_box_reg: 0.0720 (0.0720)  loss_objectness: 0.0330 (0.0330)  loss_rpn_box_reg: 0.0030 (0.0030)  time: 2.8712  data: 2.0267  max mem: 9283
# Epoch: [35]  [1000/1549]  eta: 0:06:55  lr: 0.000500  loss: 0.1467 (0.1524)  loss_classifier: 0.0631 (0.0635)  loss_box_reg: 0.0650 (0.0678)  loss_objectness: 0.0123 (0.0171)  loss_rpn_box_reg: 0.0027 (0.0042)  time: 0.7617  data: 0.0216  max mem: 9283
# Epoch: [35]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1334 (0.1533)  loss_classifier: 0.0590 (0.0644)  loss_box_reg: 0.0613 (0.0685)  loss_objectness: 0.0102 (0.0165)  loss_rpn_box_reg: 0.0034 (0.0039)  time: 0.7414  data: 0.0181  max mem: 9283
# Epoch: [35] Total time: 0:19:31 (0.7560 s / it)
# creating index...
# index created!
# Test:  [  0/368]  eta: 0:14:16  model_time: 0.2877 (0.2877)  evaluator_time: 0.0227 (0.0227)  time: 2.3281  data: 2.0076  max mem: 9283
# Test:  [100/368]  eta: 0:01:19  model_time: 0.2461 (0.2503)  evaluator_time: 0.0038 (0.0044)  time: 0.2731  data: 0.0139  max mem: 9283
# Test:  [200/368]  eta: 0:00:48  model_time: 0.2470 (0.2488)  evaluator_time: 0.0037 (0.0042)  time: 0.2772  data: 0.0168  max mem: 9283
# Test:  [300/368]  eta: 0:00:19  model_time: 0.2462 (0.2482)  evaluator_time: 0.0034 (0.0040)  time: 0.2744  data: 0.0164  max mem: 9283
# Test:  [367/368]  eta: 0:00:00  model_time: 0.2469 (0.2479)  evaluator_time: 0.0034 (0.0040)  time: 0.2713  data: 0.0159  max mem: 9283
# Test: Total time: 0:01:43 (0.2824 s / it)
# Averaged stats: model_time: 0.2469 (0.2479)  evaluator_time: 0.0034 (0.0040)
# Accumulating evaluation results...
# DONE (t=0.29s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.270
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.505
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.260
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.276
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.266
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.371
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.537
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.480
# Epoch: [36]  [   0/1549]  eta: 1:15:56  lr: 0.000500  loss: 0.1753 (0.1753)  loss_classifier: 0.0822 (0.0822)  loss_box_reg: 0.0640 (0.0640)  loss_objectness: 0.0251 (0.0251)  loss_rpn_box_reg: 0.0040 (0.0040)  time: 2.9415  data: 2.1378  max mem: 9283
# Epoch: [36]  [1000/1549]  eta: 0:06:55  lr: 0.000500  loss: 0.1512 (0.1519)  loss_classifier: 0.0655 (0.0646)  loss_box_reg: 0.0713 (0.0685)  loss_objectness: 0.0109 (0.0154)  loss_rpn_box_reg: 0.0023 (0.0035)  time: 0.7606  data: 0.0192  max mem: 9283
# Epoch: [36]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1599 (0.1528)  loss_classifier: 0.0657 (0.0645)  loss_box_reg: 0.0684 (0.0686)  loss_objectness: 0.0139 (0.0159)  loss_rpn_box_reg: 0.0035 (0.0038)  time: 0.7329  data: 0.0161  max mem: 9283
# Epoch: [36] Total time: 0:19:31 (0.7565 s / it)
# Epoch: [37]  [   0/1549]  eta: 1:38:13  lr: 0.000500  loss: 0.1176 (0.1176)  loss_classifier: 0.0412 (0.0412)  loss_box_reg: 0.0647 (0.0647)  loss_objectness: 0.0084 (0.0084)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 3.8050  data: 3.0342  max mem: 9283
# Epoch: [37]  [1000/1549]  eta: 0:06:55  lr: 0.000500  loss: 0.1374 (0.1519)  loss_classifier: 0.0597 (0.0635)  loss_box_reg: 0.0638 (0.0680)  loss_objectness: 0.0099 (0.0165)  loss_rpn_box_reg: 0.0027 (0.0040)  time: 0.7538  data: 0.0197  max mem: 9283
# Epoch: [37]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1440 (0.1516)  loss_classifier: 0.0578 (0.0637)  loss_box_reg: 0.0593 (0.0680)  loss_objectness: 0.0146 (0.0161)  loss_rpn_box_reg: 0.0028 (0.0038)  time: 0.7405  data: 0.0166  max mem: 9283
# Epoch: [37] Total time: 0:19:31 (0.7562 s / it)
# Epoch: [38]  [   0/1549]  eta: 1:14:58  lr: 0.000500  loss: 0.1581 (0.1581)  loss_classifier: 0.0810 (0.0810)  loss_box_reg: 0.0632 (0.0632)  loss_objectness: 0.0110 (0.0110)  loss_rpn_box_reg: 0.0030 (0.0030)  time: 2.9043  data: 2.0743  max mem: 9283
# Epoch: [38]  [1000/1549]  eta: 0:06:55  lr: 0.000500  loss: 0.1466 (0.1528)  loss_classifier: 0.0584 (0.0650)  loss_box_reg: 0.0609 (0.0685)  loss_objectness: 0.0099 (0.0156)  loss_rpn_box_reg: 0.0017 (0.0037)  time: 0.7526  data: 0.0181  max mem: 9283
# Epoch: [38]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1536 (0.1531)  loss_classifier: 0.0663 (0.0646)  loss_box_reg: 0.0693 (0.0686)  loss_objectness: 0.0144 (0.0161)  loss_rpn_box_reg: 0.0023 (0.0037)  time: 0.7266  data: 0.0158  max mem: 9283
# Epoch: [38] Total time: 0:19:29 (0.7547 s / it)
# Epoch: [39]  [   0/1549]  eta: 1:22:04  lr: 0.000500  loss: 0.1416 (0.1416)  loss_classifier: 0.0741 (0.0741)  loss_box_reg: 0.0571 (0.0571)  loss_objectness: 0.0082 (0.0082)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 3.1790  data: 2.2866  max mem: 9283
# Epoch: [39]  [1000/1549]  eta: 0:06:54  lr: 0.000500  loss: 0.1474 (0.1507)  loss_classifier: 0.0578 (0.0627)  loss_box_reg: 0.0668 (0.0673)  loss_objectness: 0.0086 (0.0164)  loss_rpn_box_reg: 0.0022 (0.0042)  time: 0.7504  data: 0.0178  max mem: 9283
# Epoch: [39]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1550 (0.1515)  loss_classifier: 0.0694 (0.0636)  loss_box_reg: 0.0716 (0.0680)  loss_objectness: 0.0079 (0.0161)  loss_rpn_box_reg: 0.0032 (0.0039)  time: 0.7313  data: 0.0162  max mem: 9283
# Epoch: [39] Total time: 0:19:30 (0.7554 s / it)
# Epoch: [40]  [   0/1549]  eta: 1:15:35  lr: 0.000500  loss: 0.1642 (0.1642)  loss_classifier: 0.0675 (0.0675)  loss_box_reg: 0.0724 (0.0724)  loss_objectness: 0.0209 (0.0209)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 2.9281  data: 2.0489  max mem: 9283
# Epoch: [40]  [1000/1549]  eta: 0:06:55  lr: 0.000500  loss: 0.1361 (0.1520)  loss_classifier: 0.0524 (0.0633)  loss_box_reg: 0.0651 (0.0683)  loss_objectness: 0.0118 (0.0164)  loss_rpn_box_reg: 0.0022 (0.0040)  time: 0.7538  data: 0.0179  max mem: 9283
# Epoch: [40]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1415 (0.1520)  loss_classifier: 0.0603 (0.0639)  loss_box_reg: 0.0673 (0.0687)  loss_objectness: 0.0108 (0.0156)  loss_rpn_box_reg: 0.0026 (0.0038)  time: 0.7423  data: 0.0168  max mem: 9283
# Epoch: [40] Total time: 0:19:32 (0.7572 s / it)
# creating index...
# index created!
# Test:  [  0/368]  eta: 0:14:21  model_time: 0.3208 (0.3208)  evaluator_time: 0.0076 (0.0076)  time: 2.3424  data: 2.0061  max mem: 9283
# Test:  [100/368]  eta: 0:01:19  model_time: 0.2458 (0.2502)  evaluator_time: 0.0045 (0.0048)  time: 0.2757  data: 0.0146  max mem: 9283
# Test:  [200/368]  eta: 0:00:48  model_time: 0.2460 (0.2486)  evaluator_time: 0.0044 (0.0050)  time: 0.2775  data: 0.0166  max mem: 9283
# Test:  [300/368]  eta: 0:00:19  model_time: 0.2454 (0.2484)  evaluator_time: 0.0042 (0.0049)  time: 0.2738  data: 0.0161  max mem: 9283
# Test:  [367/368]  eta: 0:00:00  model_time: 0.2452 (0.2476)  evaluator_time: 0.0041 (0.0048)  time: 0.2683  data: 0.0162  max mem: 9283
# Test: Total time: 0:01:44 (0.2831 s / it)
# Averaged stats: model_time: 0.2452 (0.2476)  evaluator_time: 0.0041 (0.0048)
# Accumulating evaluation results...
# DONE (t=0.37s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.277
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.511
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.140
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.263
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.363
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.536
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.504
# Epoch: [41]  [   0/1549]  eta: 1:15:21  lr: 0.000500  loss: 0.1599 (0.1599)  loss_classifier: 0.0816 (0.0816)  loss_box_reg: 0.0588 (0.0588)  loss_objectness: 0.0175 (0.0175)  loss_rpn_box_reg: 0.0020 (0.0020)  time: 2.9188  data: 2.0767  max mem: 9283
# Epoch: [41]  [1000/1549]  eta: 0:06:55  lr: 0.000500  loss: 0.1322 (0.1529)  loss_classifier: 0.0569 (0.0642)  loss_box_reg: 0.0588 (0.0693)  loss_objectness: 0.0124 (0.0155)  loss_rpn_box_reg: 0.0026 (0.0039)  time: 0.7567  data: 0.0219  max mem: 9283
# Epoch: [41]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1523 (0.1519)  loss_classifier: 0.0635 (0.0638)  loss_box_reg: 0.0661 (0.0686)  loss_objectness: 0.0147 (0.0157)  loss_rpn_box_reg: 0.0028 (0.0038)  time: 0.7369  data: 0.0171  max mem: 9283
# Epoch: [41] Total time: 0:19:30 (0.7555 s / it)
# Epoch: [42]  [   0/1549]  eta: 1:13:31  lr: 0.000500  loss: 0.1743 (0.1743)  loss_classifier: 0.0831 (0.0831)  loss_box_reg: 0.0635 (0.0635)  loss_objectness: 0.0221 (0.0221)  loss_rpn_box_reg: 0.0056 (0.0056)  time: 2.8480  data: 2.0568  max mem: 9283
# Epoch: [42]  [1000/1549]  eta: 0:06:55  lr: 0.000500  loss: 0.1459 (0.1504)  loss_classifier: 0.0605 (0.0627)  loss_box_reg: 0.0755 (0.0676)  loss_objectness: 0.0091 (0.0163)  loss_rpn_box_reg: 0.0023 (0.0038)  time: 0.7562  data: 0.0167  max mem: 9283
# Epoch: [42]  [1548/1549]  eta: 0:00:00  lr: 0.000500  loss: 0.1410 (0.1506)  loss_classifier: 0.0659 (0.0631)  loss_box_reg: 0.0673 (0.0682)  loss_objectness: 0.0072 (0.0156)  loss_rpn_box_reg: 0.0025 (0.0038)  time: 0.7408  data: 0.0178  max mem: 9283
# Epoch: [42] Total time: 0:19:30 (0.7559 s / it)
# Epoch: [43]  [   0/1549]  eta: 1:22:03  lr: 0.000500  loss: 0.1869 (0.1869)  loss_classifier: 0.0941 (0.0941)  loss_box_reg: 0.0808 (0.0808)  loss_objectness: 0.0093 (0.0093)  loss_rpn_box_reg: 0.0027 (0.0027)  time: 3.1787  data: 2.2455  max mem: 9283
# ...
# Epoch: [48]  [1548/1549]  eta: 0:00:00  lr: 0.000250  loss: 0.1391 (0.1472)  loss_classifier: 0.0567 (0.0615)  loss_box_reg: 0.0654 (0.0676)  loss_objectness: 0.0095 (0.0145)  loss_rpn_box_reg: 0.0020 (0.0037)  time: 0.7425  data: 0.0154  max mem: 9283
# Epoch: [48] Total time: 0:19:30 (0.7559 s / it)
# Epoch: [49]  [   0/1549]  eta: 1:18:03  lr: 0.000250  loss: 0.1777 (0.1777)  loss_classifier: 0.0821 (0.0821)  loss_box_reg: 0.0882 (0.0882)  loss_objectness: 0.0053 (0.0053)  loss_rpn_box_reg: 0.0021 (0.0021)  time: 3.0235  data: 2.1459  max mem: 9283
# Epoch: [49]  [1000/1549]  eta: 0:06:55  lr: 0.000250  loss: 0.1604 (0.1469)  loss_classifier: 0.0622 (0.0614)  loss_box_reg: 0.0721 (0.0679)  loss_objectness: 0.0126 (0.0141)  loss_rpn_box_reg: 0.0027 (0.0035)  time: 0.7533  data: 0.0177  max mem: 9283
# Epoch: [49]  [1548/1549]  eta: 0:00:00  lr: 0.000250  loss: 0.1366 (0.1484)  loss_classifier: 0.0580 (0.0622)  loss_box_reg: 0.0652 (0.0681)  loss_objectness: 0.0073 (0.0145)  loss_rpn_box_reg: 0.0026 (0.0036)  time: 0.7356  data: 0.0162  max mem: 9283
# Epoch: [49] Total time: 0:19:31 (0.7561 s / it)
# Epoch: [50]  [   0/1549]  eta: 1:27:01  lr: 0.000250  loss: 0.1183 (0.1183)  loss_classifier: 0.0598 (0.0598)  loss_box_reg: 0.0441 (0.0441)  loss_objectness: 0.0128 (0.0128)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 3.3711  data: 2.5492  max mem: 9283
# Epoch: [50]  [1000/1549]  eta: 0:06:55  lr: 0.000250  loss: 0.1402 (0.1463)  loss_classifier: 0.0576 (0.0615)  loss_box_reg: 0.0656 (0.0673)  loss_objectness: 0.0105 (0.0140)  loss_rpn_box_reg: 0.0029 (0.0036)  time: 0.7605  data: 0.0207  max mem: 9283
# Epoch: [50]  [1548/1549]  eta: 0:00:00  lr: 0.000250  loss: 0.1483 (0.1474)  loss_classifier: 0.0634 (0.0619)  loss_box_reg: 0.0606 (0.0677)  loss_objectness: 0.0151 (0.0142)  loss_rpn_box_reg: 0.0030 (0.0037)  time: 0.7447  data: 0.0172  max mem: 9283
# Epoch: [50] Total time: 0:19:30 (0.7554 s / it)
# creating index...
# index created!
# Test:  [  0/368]  eta: 0:15:14  model_time: 0.2986 (0.2986)  evaluator_time: 0.0068 (0.0068)  time: 2.4855  data: 2.1718  max mem: 9283
# Test:  [100/368]  eta: 0:01:19  model_time: 0.2456 (0.2484)  evaluator_time: 0.0039 (0.0040)  time: 0.2730  data: 0.0141  max mem: 9283
# Test:  [200/368]  eta: 0:00:48  model_time: 0.2463 (0.2476)  evaluator_time: 0.0037 (0.0041)  time: 0.2750  data: 0.0154  max mem: 9283
# Test:  [300/368]  eta: 0:00:19  model_time: 0.2467 (0.2477)  evaluator_time: 0.0037 (0.0041)  time: 0.2765  data: 0.0169  max mem: 9283
# Test:  [367/368]  eta: 0:00:00  model_time: 0.2462 (0.2473)  evaluator_time: 0.0036 (0.0040)  time: 0.2689  data: 0.0165  max mem: 9283
# Test: Total time: 0:01:44 (0.2826 s / it)
# Averaged stats: model_time: 0.2462 (0.2473)  evaluator_time: 0.0036 (0.0040)
# Accumulating evaluation results...
# DONE (t=0.39s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.283
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.529
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.264
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.374
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.536
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.541
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.552
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.483
# Epoch: [51]  [   0/1549]  eta: 1:30:58  lr: 0.000250  loss: 0.1384 (0.1384)  loss_classifier: 0.0586 (0.0586)  loss_box_reg: 0.0627 (0.0627)  loss_objectness: 0.0135 (0.0135)  loss_rpn_box_reg: 0.0035 (0.0035)  time: 3.5238  data: 2.7088  max mem: 9283
# Epoch: [51]  [1000/1549]  eta: 0:06:55  lr: 0.000250  loss: 0.1351 (0.1474)  loss_classifier: 0.0549 (0.0610)  loss_box_reg: 0.0642 (0.0675)  loss_objectness: 0.0082 (0.0150)  loss_rpn_box_reg: 0.0024 (0.0039)  time: 0.7688  data: 0.0223  max mem: 9283
# Epoch: [51]  [1548/1549]  eta: 0:00:00  lr: 0.000250  loss: 0.1435 (0.1473)  loss_classifier: 0.0683 (0.0616)  loss_box_reg: 0.0643 (0.0675)  loss_objectness: 0.0105 (0.0145)  loss_rpn_box_reg: 0.0018 (0.0037)  time: 0.7370  data: 0.0159  max mem: 9283
# Epoch: [51] Total time: 0:19:31 (0.7563 s / it)
# Epoch: [52]  [   0/1549]  eta: 1:32:07  lr: 0.000250  loss: 0.1870 (0.1870)  loss_classifier: 0.0926 (0.0926)  loss_box_reg: 0.0788 (0.0788)  loss_objectness: 0.0130 (0.0130)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 3.5685  data: 2.6608  max mem: 9283
# Epoch: [52]  [1000/1549]  eta: 0:06:54  lr: 0.000250  loss: 0.1329 (0.1479)  loss_classifier: 0.0561 (0.0620)  loss_box_reg: 0.0646 (0.0682)  loss_objectness: 0.0113 (0.0140)  loss_rpn_box_reg: 0.0017 (0.0037)  time: 0.7408  data: 0.0161  max mem: 9283
# Epoch: [52]  [1548/1549]  eta: 0:00:00  lr: 0.000250  loss: 0.1334 (0.1472)  loss_classifier: 0.0529 (0.0616)  loss_box_reg: 0.0648 (0.0675)  loss_objectness: 0.0115 (0.0144)  loss_rpn_box_reg: 0.0030 (0.0037)  time: 0.7354  data: 0.0159  max mem: 9283
# Epoch: [52] Total time: 0:19:28 (0.7543 s / it)
# Epoch: [53]  [   0/1549]  eta: 1:19:45  lr: 0.000250  loss: 0.1287 (0.1287)  loss_classifier: 0.0507 (0.0507)  loss_box_reg: 0.0573 (0.0573)  loss_objectness: 0.0186 (0.0186)  loss_rpn_box_reg: 0.0020 (0.0020)  time: 3.0892  data: 2.1951  max mem: 9283
# Epoch: [53]  [1000/1549]  eta: 0:06:54  lr: 0.000250  loss: 0.1420 (0.1458)  loss_classifier: 0.0638 (0.0612)  loss_box_reg: 0.0631 (0.0673)  loss_objectness: 0.0102 (0.0139)  loss_rpn_box_reg: 0.0028 (0.0034)  time: 0.7473  data: 0.0154  max mem: 9283
# Epoch: [53]  [1548/1549]  eta: 0:00:00  lr: 0.000250  loss: 0.1294 (0.1471)  loss_classifier: 0.0559 (0.0616)  loss_box_reg: 0.0641 (0.0677)  loss_objectness: 0.0088 (0.0141)  loss_rpn_box_reg: 0.0028 (0.0037)  time: 0.7455  data: 0.0189  max mem: 9283
# Epoch: [53] Total time: 0:19:31 (0.7561 s / it)
# Epoch: [54]  [   0/1549]  eta: 1:17:46  lr: 0.000250  loss: 0.1828 (0.1828)  loss_classifier: 0.0721 (0.0721)  loss_box_reg: 0.1033 (0.1033)  loss_objectness: 0.0049 (0.0049)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 3.0126  data: 2.1225  max mem: 9283
# Epoch: [54]  [1000/1549]  eta: 0:06:55  lr: 0.000250  loss: 0.1576 (0.1476)  loss_classifier: 0.0581 (0.0620)  loss_box_reg: 0.0784 (0.0674)  loss_objectness: 0.0121 (0.0143)  loss_rpn_box_reg: 0.0024 (0.0039)  time: 0.7525  data: 0.0160  max mem: 9283
# Epoch: [54]  [1548/1549]  eta: 0:00:00  lr: 0.000250  loss: 0.1451 (0.1476)  loss_classifier: 0.0628 (0.0620)  loss_box_reg: 0.0687 (0.0678)  loss_objectness: 0.0095 (0.0142)  loss_rpn_box_reg: 0.0022 (0.0036)  time: 0.7306  data: 0.0156  max mem: 9283
# Epoch: [54] Total time: 0:19:30 (0.7554 s / it)
# Epoch: [55]  [   0/1549]  eta: 1:20:55  lr: 0.000250  loss: 0.1007 (0.1007)  loss_classifier: 0.0413 (0.0413)  loss_box_reg: 0.0521 (0.0521)  loss_objectness: 0.0041 (0.0041)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 3.1344  data: 2.2510  max mem: 9283
# Epoch: [55]  [1000/1549]  eta: 0:06:55  lr: 0.000250  loss: 0.1520 (0.1463)  loss_classifier: 0.0655 (0.0609)  loss_box_reg: 0.0734 (0.0675)  loss_objectness: 0.0095 (0.0142)  loss_rpn_box_reg: 0.0024 (0.0037)  time: 0.7538  data: 0.0174  max mem: 9283
# Epoch: [55]  [1548/1549]  eta: 0:00:00  lr: 0.000250  loss: 0.1483 (0.1465)  loss_classifier: 0.0607 (0.0609)  loss_box_reg: 0.0678 (0.0673)  loss_objectness: 0.0111 (0.0144)  loss_rpn_box_reg: 0.0022 (0.0038)  time: 0.7275  data: 0.0160  max mem: 9283
# Epoch: [55] Total time: 0:19:29 (0.7553 s / it)
# creating index...
# index created!
# Test:  [  0/368]  eta: 0:15:47  model_time: 0.3047 (0.3047)  evaluator_time: 0.0080 (0.0080)  time: 2.5742  data: 2.2534  max mem: 9283
# Test:  [100/368]  eta: 0:01:20  model_time: 0.2449 (0.2481)  evaluator_time: 0.0046 (0.0074)  time: 0.2750  data: 0.0159  max mem: 9283
# Test:  [200/368]  eta: 0:00:48  model_time: 0.2463 (0.2472)  evaluator_time: 0.0044 (0.0063)  time: 0.2773  data: 0.0162  max mem: 9283
# Test:  [300/368]  eta: 0:00:19  model_time: 0.2447 (0.2472)  evaluator_time: 0.0047 (0.0058)  time: 0.2733  data: 0.0146  max mem: 9283
# Test:  [367/368]  eta: 0:00:00  model_time: 0.2442 (0.2467)  evaluator_time: 0.0043 (0.0056)  time: 0.2679  data: 0.0148  max mem: 9283
# Test: Total time: 0:01:43 (0.2824 s / it)
# Averaged stats: model_time: 0.2442 (0.2467)  evaluator_time: 0.0043 (0.0056)
# Accumulating evaluation results...
# DONE (t=0.41s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.528
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.130
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.297
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.266
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.544
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.505
# Epoch: [56]  [   0/1549]  eta: 1:22:33  lr: 0.000250  loss: 0.1287 (0.1287)  loss_classifier: 0.0546 (0.0546)  loss_box_reg: 0.0658 (0.0658)  loss_objectness: 0.0075 (0.0075)  loss_rpn_box_reg: 0.0009 (0.0009)  time: 3.1977  data: 2.1328  max mem: 9283
# Epoch: [56]  [1000/1549]  eta: 0:06:54  lr: 0.000250  loss: 0.1569 (0.1454)  loss_classifier: 0.0660 (0.0607)  loss_box_reg: 0.0654 (0.0673)  loss_objectness: 0.0126 (0.0137)  loss_rpn_box_reg: 0.0032 (0.0037)  time: 0.7501  data: 0.0169  max mem: 9283
# Epoch: [56]  [1548/1549]  eta: 0:00:00  lr: 0.000250  loss: 0.1334 (0.1460)  loss_classifier: 0.0574 (0.0611)  loss_box_reg: 0.0708 (0.0675)  loss_objectness: 0.0115 (0.0138)  loss_rpn_box_reg: 0.0021 (0.0036)  time: 0.7393  data: 0.0167  max mem: 9283
# Epoch: [56] Total time: 0:19:29 (0.7550 s / it)
# Epoch: [57]  [   0/1549]  eta: 1:18:28  lr: 0.000250  loss: 0.1706 (0.1706)  loss_classifier: 0.0689 (0.0689)  loss_box_reg: 0.0898 (0.0898)  loss_objectness: 0.0098 (0.0098)  loss_rpn_box_reg: 0.0019 (0.0019)  time: 3.0396  data: 2.2000  max mem: 9283
# Epoch: [57]  [1000/1549]  eta: 0:06:55  lr: 0.000250  loss: 0.1323 (0.1448)  loss_classifier: 0.0602 (0.0602)  loss_box_reg: 0.0620 (0.0676)  loss_objectness: 0.0085 (0.0136)  loss_rpn_box_reg: 0.0029 (0.0034)  time: 0.7629  data: 0.0175  max mem: 9283
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f8f0385ed30>
# Traceback (most recent call last):
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1301, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/multiprocessing/popen_fork.py", line 44, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6609/1496413834.py in <module>
#       3 start_time = time.time()
#       4 for epoch in range(args.epochs):
# ----> 5     train_one_epoch(model, optimizer, train_loader, device, epoch, args.print_freq)
#       6     lr_scheduler.step()
#       7
#
# ~/project/scl/torchvision_Detection/notebooks/../engine.py in train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq)
#      30         # print(targets)
#      31
# ---> 32         loss_dict = model(images, targets)
#      33
#      34         losses = sum(loss for loss in loss_dict.values())
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/project/scl/torchvision_Detection/notebooks/../models/detection/generalized_rcnn.py in forward(self, images, targets)
#      99         if isinstance(features, torch.Tensor):
#     100             features = OrderedDict([("0", features)])
# --> 101         proposals, proposal_losses = self.rpn(images, features, targets)
#     102         detections, detector_losses = self.roi_heads(features, proposals, images.image_sizes, targets)
#     103         detections = self.transform.postprocess(detections, images.image_sizes, original_image_sizes)
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/project/scl/torchvision_Detection/notebooks/../models/detection/rpn.py in forward(self, images, features, targets)
#     340         features = list(features.values())
#     341         objectness, pred_bbox_deltas = self.head(features)
# --> 342         anchors = self.anchor_generator(images, features)
#     343
#     344         num_images = len(anchors)
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/project/scl/torchvision_Detection/notebooks/../models/detection/anchor_utils.py in forward(self, image_list, feature_maps)
#     120         image_size = image_list.tensors.shape[-2:]
#     121         dtype, device = feature_maps[0].dtype, feature_maps[0].device
# --> 122         strides = [
#     123             [
#     124                 torch.tensor(image_size[0] // g[0], dtype=torch.int64, device=device),
#
# ~/project/scl/torchvision_Detection/notebooks/../models/detection/anchor_utils.py in <listcomp>(.0)
#     122         strides = [
#     123             [
# --> 124                 torch.tensor(image_size[0] // g[0], dtype=torch.int64, device=device),
#     125                 torch.tensor(image_size[1] // g[1], dtype=torch.int64, device=device),
#     126             ]
#
# KeyboardInterrupt:

# %%
model
